# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# Install tmdbsimple (only need to run once)
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /Users/swaghanaian/opt/anaconda3/envs/dojo-env/lib/python3.8/site-packages (4.64.1)

# %%
# Load API Credentials
with open('/Users/swaghanaian/secret/yelp_api.json') as f: 
    login = json.load(f)
# Instantiate YelpAPI Variable
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)

# %%
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# set our API call parameters 
LOCATION = 'brooklyn,NY'
TERM = 'Pizza'

# %%
# Specifying JSON_FILE filename (can include a folder)
# include the search terms in the filename
JSON_FILE = "Data/results_in_progress_NY_pizza.json"
JSON_FILE
# Out:
# 'Data/results_in_progress_NY_pizza.json'

# %%
def create_json_file(JSON_FILE,  delete_if_exists=False):
    
    ## Check if JSON_FILE exists
    file_exists = os.path.isfile(JSON_FILE)
    
    ## If it DOES exist:
    if file_exists == True:
        
        ## Check if user wants to delete if exists
        if delete_if_exists==True:
            
            print(f"[!] {JSON_FILE} already exists. Deleting previous file...")
            ## delete file and confirm it no longer exits.
            os.remove(JSON_FILE)
        else:
            print(f"[i] {JSON_FILE} already exists.")            
            
            
    ## If it does NOT exist:
    else:
        
        ## INFORM USER AND SAVE EMPTY LIST
        print(f"[i] {JSON_FILE} not found. Saving empty list to new file.")
        
        ## CREATE ANY NEEDED FOLDERS
        # Get the Folder Name only
        folder = os.path.dirname(JSON_FILE)
        
        ## If JSON_FILE included a folder:
        if len(folder)>0:
            # create the folder
            os.makedirs(folder,exist_ok=True)
        ## Save empty list to start the json file
        with open(JSON_FILE,'w') as f:
            json.dump([],f)

# %%
## Create a new empty json file (exist the previous if it exists)
create_json_file(JSON_FILE, delete_if_exists=True)
## Load previous results and use len of results for offset
with open(JSON_FILE,'r') as f:
    previous_results = json.load(f)
    
## set offset based on previous results
n_results = len(previous_results)
print(f'- {n_results} previous results found.')
# use our yelp_api variable's search_query method to perform our API call
results = yelp_api.search_query(location=LOCATION,
                                term=TERM,
                               offset=n_results)
## How many results total?
total_results = results['total']
## How many did we get the details for?
results_per_page = len(results['businesses'])
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total']-n_results)/ results_per_page)
n_pages
# Out:
# [i] Data/results_in_progress_NY_pizza.json not found. Saving empty list to new file.
# - 0 previous results found.
# 560

# %%
for i in tqdm_notebook( range(1,n_pages+1)):
    
    ## Read in results in progress file and check the length
    with open(JSON_FILE, 'r') as f:
        previous_results = json.load(f)
    ## save number of results for to use as offset
    n_results = len(previous_results)
    
    if (n_results + results_per_page) > 1000:
        print('Exceeded 1000 api calls. Stopping loop.')
        break
    
    ## use n_results as the OFFSET 
    results = yelp_api.search_query(location=LOCATION,
                                    term=TERM, 
                                    offset=n_results)
    
    
    
    ## append new results and save to file
    previous_results.extend(results['businesses'])
    
    # display(previous_results)
    with open(JSON_FILE,'w') as f:
        json.dump(previous_results,f)
    
    time.sleep(.2)
# Out:
#   0%|          | 0/560 [00:00<?, ?it/s]
# Exceeded 1000 api calls. Stopping loop.

# %%
# load final results in a data frame
final_df = pd.read_json(JSON_FILE)
display(final_df.head(), final_df.tail())
# Out:
#                        id                                  alias  \
# 0  tpcCX_SHaNXqAzXOzbluJQ                    fini-pizza-brooklyn
# 1  ysqgdbSrezXgVwER2kQWKA                    julianas-brooklyn-3
# 2  xRiLLXjeM2wOvVTYJH2__A    barboncino-pizza-and-bar-brooklyn-2
# 3  3VJwpmmeoPlCN3J5p5miEQ  brooklyns-homeslice-pizzeria-brooklyn
# 4  C8j0q4Ma_S5hBGuAI-aaww                 di-fara-pizza-brooklyn
#
#                             name  \
# 0                     Fini Pizza
# 1                      Juliana's
# 2         Barboncino Pizza & Bar
# 3  Brooklyn's Homeslice Pizzeria
# 4                  Di Fara Pizza
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/UEW7bE...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/OCDZ4n...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/vOe8cj...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/PFbKEy...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/Et320n...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/fini-pizza-brooklyn?a...            12
# 1  https://www.yelp.com/biz/julianas-brooklyn-3?a...          2523
# 2  https://www.yelp.com/biz/barboncino-pizza-and-...          1079
# 3  https://www.yelp.com/biz/brooklyns-homeslice-p...           181
# 4  https://www.yelp.com/biz/di-fara-pizza-brookly...          3837
#
#                                           categories  rating  \
# 0             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 1             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 2  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 3             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 4             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                          coordinates        transactions  \
# 0     {'latitude': 40.71348, 'longitude': -73.96182}                  []
# 1  {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 2     {'latitude': 40.67206, 'longitude': -73.95717}          [delivery]
# 3   {'latitude': 40.680702, 'longitude': -73.967455}  [pickup, delivery]
# 4   {'latitude': 40.625093, 'longitude': -73.961531}  [pickup, delivery]
#
#                                             location         phone  \
# 0  {'address1': '305 Bedford Ave', 'address2': ''...
# 1  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 2  {'address1': '781 Franklin Ave', 'address2': '...  +17184838834
# 3  {'address1': '567 Vanderbilt Ave', 'address2':...  +17183999000
# 4  {'address1': '1424 Ave J', 'address2': '', 'ad...  +17182581367
#
#     display_phone     distance price
# 0                  7054.533194   NaN
# 1  (718) 596-6700  7226.454630    $$
# 2  (718) 483-8834  2663.491653    $$
# 3  (718) 399-9000  3945.532545     $
# 4  (718) 258-1367  3559.746344    $$
#                          id                                  alias  \
# 995  0eHYheq3fwDGKAaGtxUGtQ     panino-toasty-delicious-brooklyn-3
# 996  VrP6mI9Ihf2qt8dH6XwnYg               proto-s-pizza-new-york-2
# 997  dWBDxX4E_QDYxLRGPzU5Jg  bene-restaurant-and-pizzeria-brooklyn
# 998  wKku3dhD7ZUT1eGQxfY7uA              robertas-pizza-new-york-3
# 999  QY2VGbMfun6BCJCT6l_lcg        friendly-gourmet-pizza-new-york
#
#                            name  \
# 995    Panino Toasty Delicious
# 996               Proto’s Pizza
# 997  Bene Restaurant & Pizzeria
# 998             Roberta's Pizza
# 999      Friendly Gourmet Pizza
#
#                                              image_url  is_closed  \
# 995  https://s3-media2.fl.yelpcdn.com/bphoto/gPzjAS...      False
# 996  https://s3-media2.fl.yelpcdn.com/bphoto/AdbSxI...      False
# 997  https://s3-media3.fl.yelpcdn.com/bphoto/YKcBna...      False
# 998  https://s3-media2.fl.yelpcdn.com/bphoto/IQaAqs...      False
# 999  https://s3-media3.fl.yelpcdn.com/bphoto/r0H1Du...      False
#
#                                                    url  review_count  \
# 995  https://www.yelp.com/biz/panino-toasty-delicio...             1
# 996  https://www.yelp.com/biz/proto-s-pizza-new-yor...           111
# 997  https://www.yelp.com/biz/bene-restaurant-and-p...            57
# 998  https://www.yelp.com/biz/robertas-pizza-new-yo...            37
# 999  https://www.yelp.com/biz/friendly-gourmet-pizz...            61
#
#                                             categories  rating  \
# 995  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     5.0
# 996             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 997             [{'alias': 'pizza', 'title': 'Pizza'}]     2.5
# 998             [{'alias': 'pizza', 'title': 'Pizza'}]     3.5
# 999             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                            coordinates        transactions  \
# 995       {'latitude': 40.63206, 'longitude': -73.995}  [pickup, delivery]
# 996   {'latitude': 40.725353, 'longitude': -73.989746}  [pickup, delivery]
# 997  {'latitude': 40.6547993572564, 'longitude': -7...  [pickup, delivery]
# 998     {'latitude': 40.75686, 'longitude': -73.97228}                  []
# 999      {'latitude': 40.70925, 'longitude': -74.0088}  [pickup, delivery]
#
#                                               location         phone  \
# 995  {'address1': '5401 13th Ave', 'address2': None...  +17185766839
# 996  {'address1': '50 2nd Ave', 'address2': None, '...  +12124324044
# 997  {'address1': '157 Prospect Park SW', 'address2...  +17186860046
# 998  {'address1': '570 Lexington Ave', 'address2': ...
# 999  {'address1': '59 Nassau St', 'address2': '', '...  +12127911800
#
#       display_phone      distance price
# 995  (718) 576-6839   5203.292145   NaN
# 996  (212) 432-4044   9165.059693     $
# 997  (718) 686-0046   2895.130837     $
# 998                  11949.812650   NaN
# 999  (212) 791-1800   8630.902446     $

# %%
# check for duplicate results
final_df.replace("'",'"')
# Out:
#                          id                                  alias  \
# 0    tpcCX_SHaNXqAzXOzbluJQ                    fini-pizza-brooklyn
# 1    ysqgdbSrezXgVwER2kQWKA                    julianas-brooklyn-3
# 2    xRiLLXjeM2wOvVTYJH2__A    barboncino-pizza-and-bar-brooklyn-2
# 3    3VJwpmmeoPlCN3J5p5miEQ  brooklyns-homeslice-pizzeria-brooklyn
# 4    C8j0q4Ma_S5hBGuAI-aaww                 di-fara-pizza-brooklyn
# ..                      ...                                    ...
# 995  0eHYheq3fwDGKAaGtxUGtQ     panino-toasty-delicious-brooklyn-3
# 996  VrP6mI9Ihf2qt8dH6XwnYg               proto-s-pizza-new-york-2
# 997  dWBDxX4E_QDYxLRGPzU5Jg  bene-restaurant-and-pizzeria-brooklyn
# 998  wKku3dhD7ZUT1eGQxfY7uA              robertas-pizza-new-york-3
# 999  QY2VGbMfun6BCJCT6l_lcg        friendly-gourmet-pizza-new-york
#
#                               name  \
# 0                       Fini Pizza
# 1                        Juliana's
# 2           Barboncino Pizza & Bar
# 3    Brooklyn's Homeslice Pizzeria
# 4                    Di Fara Pizza
# ..                             ...
# 995       Panino Toasty Delicious
# 996                  Proto’s Pizza
# 997     Bene Restaurant & Pizzeria
# 998                Roberta's Pizza
# 999         Friendly Gourmet Pizza
#
#                                              image_url  is_closed  \
# 0    https://s3-media3.fl.yelpcdn.com/bphoto/UEW7bE...      False
# 1    https://s3-media1.fl.yelpcdn.com/bphoto/OCDZ4n...      False
# 2    https://s3-media1.fl.yelpcdn.com/bphoto/vOe8cj...      False
# 3    https://s3-media1.fl.yelpcdn.com/bphoto/PFbKEy...      False
# 4    https://s3-media2.fl.yelpcdn.com/bphoto/Et320n...      False
# ..                                                 ...        ...
# 995  https://s3-media2.fl.yelpcdn.com/bphoto/gPzjAS...      False
# 996  https://s3-media2.fl.yelpcdn.com/bphoto/AdbSxI...      False
# 997  https://s3-media3.fl.yelpcdn.com/bphoto/YKcBna...      False
# 998  https://s3-media2.fl.yelpcdn.com/bphoto/IQaAqs...      False
# 999  https://s3-media3.fl.yelpcdn.com/bphoto/r0H1Du...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/fini-pizza-brooklyn?a...            12
# 1    https://www.yelp.com/biz/julianas-brooklyn-3?a...          2523
# 2    https://www.yelp.com/biz/barboncino-pizza-and-...          1079
# 3    https://www.yelp.com/biz/brooklyns-homeslice-p...           181
# 4    https://www.yelp.com/biz/di-fara-pizza-brookly...          3837
# ..                                                 ...           ...
# 995  https://www.yelp.com/biz/panino-toasty-delicio...             1
# 996  https://www.yelp.com/biz/proto-s-pizza-new-yor...           111
# 997  https://www.yelp.com/biz/bene-restaurant-and-p...            57
# 998  https://www.yelp.com/biz/robertas-pizza-new-yo...            37
# 999  https://www.yelp.com/biz/friendly-gourmet-pizz...            61
#
#                                             categories  rating  \
# 0               [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 1               [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 2    [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 3               [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 4               [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# ..                                                 ...     ...
# 995  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     5.0
# 996             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 997             [{'alias': 'pizza', 'title': 'Pizza'}]     2.5
# 998             [{'alias': 'pizza', 'title': 'Pizza'}]     3.5
# 999             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
#
#                                            coordinates        transactions  \
# 0       {'latitude': 40.71348, 'longitude': -73.96182}                  []
# 1    {'latitude': 40.70274718768062, 'longitude': -...          [delivery]
# 2       {'latitude': 40.67206, 'longitude': -73.95717}          [delivery]
# 3     {'latitude': 40.680702, 'longitude': -73.967455}  [pickup, delivery]
# 4     {'latitude': 40.625093, 'longitude': -73.961531}  [pickup, delivery]
# ..                                                 ...                 ...
# 995       {'latitude': 40.63206, 'longitude': -73.995}  [pickup, delivery]
# 996   {'latitude': 40.725353, 'longitude': -73.989746}  [pickup, delivery]
# 997  {'latitude': 40.6547993572564, 'longitude': -7...  [pickup, delivery]
# 998     {'latitude': 40.75686, 'longitude': -73.97228}                  []
# 999      {'latitude': 40.70925, 'longitude': -74.0088}  [pickup, delivery]
#
#                                               location         phone  \
# 0    {'address1': '305 Bedford Ave', 'address2': ''...
# 1    {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 2    {'address1': '781 Franklin Ave', 'address2': '...  +17184838834
# 3    {'address1': '567 Vanderbilt Ave', 'address2':...  +17183999000
# 4    {'address1': '1424 Ave J', 'address2': '', 'ad...  +17182581367
# ..                                                 ...           ...
# 995  {'address1': '5401 13th Ave', 'address2': None...  +17185766839
# 996  {'address1': '50 2nd Ave', 'address2': None, '...  +12124324044
# 997  {'address1': '157 Prospect Park SW', 'address2...  +17186860046
# 998  {'address1': '570 Lexington Ave', 'address2': ...
# 999  {'address1': '59 Nassau St', 'address2': '', '...  +12127911800
#
#       display_phone      distance price
# 0                     7054.533194   NaN
# 1    (718) 596-6700   7226.454630    $$
# 2    (718) 483-8834   2663.491653    $$
# 3    (718) 399-9000   3945.532545     $
# 4    (718) 258-1367   3559.746344    $$
# ..              ...           ...   ...
# 995  (718) 576-6839   5203.292145   NaN
# 996  (212) 432-4044   9165.059693     $
# 997  (718) 686-0046   2895.130837     $
# 998                  11949.812650   NaN
# 999  (212) 791-1800   8630.902446     $
#
# [1000 rows x 16 columns]

# %%
# check for duplicate ID's 
final_df.duplicated(subset='id').sum()
# Out:
# 171

# %%
## Drop duplicate ids and confirm there are no more duplicates
final_df = final_df.drop_duplicates(subset='id')
final_df.duplicated(subset='id').sum()
# Out:
# 0

# %%
# save the final results to a compressed csv
final_df.to_csv('Data/final_results_NY_pizza.csv.gz', compression='gzip',index=False)
